# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
data = pandas.read_csv("../data/CompanyBankruptcyData.csv")
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
data['Bankrupt?'].value_counts()
# Out:
# 0    6599
# 1     220
# Name: Bankrupt?, dtype: int64

# %%
bankrupt_df = pd.DataFrame(data=data['Bankrupt?'].value_counts())

plt.bar(x=bankrupt_df.index, height=bankrupt_df['Bankrupt?'])
# Out:
# <BarContainer object of 2 artists>

# %%
corr_matrix = data.corr()


plt.figure(figsize=(30,15))
sns.heatmap(corr_matrix)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Notes
#
# #### Options for regression targets:
# -
# -
# -
#
# <br><br>
#
# #### Options for classification labels:
# - Bankruptcy?: is binary class. 1=bankrupt, 0=not bankrupt. (col 0)
# - Liability-Assets Flag: 1 if Total Liability exceeds Total Assets, 0 otherwise (col 85)
# - Net Income Flag: 1 if Net Income is Negative for the last two years, 0 otherwise (col 94)
